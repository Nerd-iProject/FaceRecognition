# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# %cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %% [markdown]
# ### Mounting to google drive

# %%
from google.colab import drive
from os.path import join
ROOT = '/content/drive'
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content/sample_data'

# %%
# %cd ..
# Out:
# /content

# %%
# %cd drive/
# Out:
# /content/drive

# %%
# %ls
# Out:
# MyDrive/

# %%
# %cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %ls
# Out:
# 'Colab Notebooks'/

# %%
# %cd Colab\ Notebooks/ProjectData/FaceRecognition/
# Out:
# /content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition

# %% [markdown]
# ### Connecting to the GITHUB

# %%
google_drive_path = "/content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition"
git_user = "SOUHARDYAADHIKARY1999"
git_user_main="SuranjanDaw"
git_token = "aab5e11eebf0734c1132506d8cbda10723880e65"
git_repo = "FaceRecognition"

git_path = "https://" + git_token + "@github.com/" + git_user_main + "/" + git_repo + ".git"
print(git_path)
print(google_drive_path)
# Out:
# https://aab5e11eebf0734c1132506d8cbda10723880e65@github.com/SuranjanDaw/FaceRecognition.git
# /content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# %cd  {google_drive_path}
# Out:
# /content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# !git clone "{git_path}"
# Out:
# Cloning into 'FaceRecognition'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 129 (delta 26), reused 106 (delta 15), pack-reused 0
# Receiving objects: 100% (129/129), 48.84 MiB | 13.56 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# Checking out files: 100% (70/70), done.

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/ProjectData/FaceRecognition'

# %%
# !git branch
# Out:
# * master

# %%
# %cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks/ProjectData

# %%
# %cd FaceRecognition/
# Out:
# /content/drive/My Drive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# !git add .

# %%
# !git config --global user.email "souhardyaadhikary86942@gmail.com"
# !git config --global user.name "SOUHARDYAADHIKARY1999"

# %%
# !git commit -m "new changes"
# Out:
# [master 7cb85b3] new changes
#  5 files changed, 4 insertions(+), 2 deletions(-)
#  create mode 100644 Environment_setup(souhardya).ipynb
#  create mode 100644 Environment_setup(suranjan).ipynb
#  delete mode 100644 Environment_setup.ipynb
#  create mode 160000 FaceRecognition
#  rewrite ImageDetection.ipynb (99%)

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
