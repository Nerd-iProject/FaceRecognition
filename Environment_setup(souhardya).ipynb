# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# sample_data/

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# %cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %% [markdown]
# ### Mounting to google drive

# %%
from google.colab import drive
from os.path import join
ROOT = '/content/drive'
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content/sample_data'

# %%
# %cd ..
# Out:
# /content

# %%
# %cd drive/
# Out:
# /content/drive

# %%
# %ls
# Out:
# MyDrive/

# %%
# %cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %ls
# Out:
# 'Colab Notebooks'/

# %%
# %cd Colab\ Notebooks/ProjectData/FaceRecognition/
# Out:
# /content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition

# %% [markdown]
# ### Connecting to the GITHUB

# %%
google_drive_path = "/content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition"
git_user = "Nerd-iProject"
git_token = "12e71a8f61a2c9e248b5437fa72811387c7d3ffa"
git_repo = "FaceRecognition"

git_path = "https://" + git_token + "@github.com/" + git_user + "/" + git_repo + ".git"
#git_path = "https://github.com/" + git_user + "/" + git_repo + ".git"
#git_path="https://github.com/Nerd-iProject/FaceRecognition.git"

print(git_path)
if git_path==str("https://github.com/Nerd-iProject/FaceRecognition.git"):
  print("right")
print(google_drive_path)
# Out:
# https://12e71a8f61a2c9e248b5437fa72811387c7d3ffa@github.com/Nerd-iProject/FaceRecognition.git
# /content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# %cd  {google_drive_path}
# Out:
# /content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# !git clone "{git_path}"
# Out:
# fatal: destination path 'FaceRecognition' already exists and is not an empty directory.

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ProjectData/FaceRecognition'

# %%
# !git branch
# Out:
# * main

# %%
# %cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks/ProjectData

# %%
# %cd FaceRecognition/
# Out:
# /content/drive/My Drive/Colab Notebooks/ProjectData/FaceRecognition

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/ProjectData/FaceRecognition/.git/

# %%
# !git config --global user.email "nerdiproject4thyearai@gmail.com"
# !git config --global user.name "Nerd-iProject"

# %%
#!git status

# %%
# !git add .

# %%
# !git commit -m "new changes"
# Out:
# [main 5fb61bb] new changes
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Environment_setup(souhardya).ipynb (61%)

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
